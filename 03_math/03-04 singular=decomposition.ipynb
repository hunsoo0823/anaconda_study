# %%
from numpy.linalg import svd
import numpy as np

A =  np.array([[3, -1], [1,3], [1,1]])
U, S, VT = svd(A)

# %%
U
# Out:
# array([[-4.08248290e-01,  8.94427191e-01, -1.82574186e-01],
#        [-8.16496581e-01, -4.47213595e-01, -3.65148372e-01],
#        [-4.08248290e-01, -1.94289029e-16,  9.12870929e-01]])

# %%
S
# Out:
# array([3.46410162, 3.16227766])

# %%
np.diag(S, 1)[:, 1:]
# Out:
# array([[3.46410162, 0.        ],
#        [0.        , 3.16227766],
#        [0.        , 0.        ]])

# %%
VT
# Out:
# array([[-0.70710678, -0.70710678],
#        [ 0.70710678, -0.70710678]])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-261344d3fc4c> in <module>
# ----> 1 U @ np.daig(S, 1)[:, 1:] @ VT
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/__init__.py in __getattr__(attr)
#     212                 return Tester
#     213             else:
# --> 214                 raise AttributeError("module {!r} has no attribute "
#     215                                      "{!r}".format(__name__, attr))
#     216
#
# AttributeError: module 'numpy' has no attribute 'daig'
