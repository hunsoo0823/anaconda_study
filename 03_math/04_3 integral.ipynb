# %%
import sympy

sympy.init_printing(use_latex='mathjax')

# %%
x, y = sympy.symbols('x y')
f = x * sympy.exp(x) + sympy.exp(x)
f
# Out:
#    x    x
# x⋅ℯ  + ℯ

# %%
sympy.integrate(f)
# Out:
#    x
# x⋅ℯ

# %%
x, y = sympy.symbols('x,y')
f = 2 * x + y
f
# Out:
# 2⋅x + y

# %%
sympy.integrate(f, x)
# Out:
#  2
# x  + x⋅y

# %%
f = 3 * x **2
f
# Out:
#    2
# 3⋅x

# %%
sympy.integrate(f, x)
# Out:
#  3
# x

# %%
f = 3 * x ** 2 - 6 * x + 1
sympy.integrate(f, x)
# Out:
#  3      2
# x  - 3⋅x  + x

# %%
f = 2 + 6 * x + 4 * sympy.exp(x) + 5 / x
sympy.integrate(f, x)
# Out:
#    2            x
# 3⋅x  + 2⋅x + 4⋅ℯ  + 5⋅log(x)

# %%
f = 2 * x / x ** 2 - 1
sympy.integrate(f, x)
# Out:
# -x + 2⋅log(x)

# %%
f = x * y * sympy.exp(x**2+y**2)
f
# Out:
#       2    2
#      x  + y
# x⋅y⋅ℯ

# %%
sympy.integrate(f, x, y)
# Out:
#   2    2
#  x  + y
# ℯ
# ────────
#    4

# %%
x, y = sympy.symbols('x y')
f = x ** 3 - 3 * x ** 2 + x + 6
f
# Out:
#  3      2
# x  - 3⋅x  + x + 6

# %%
# 부정 적분
F =  sympy.integrate(f)
F
# Out:
#  4         2
# x     3   x
# ── - x  + ── + 6⋅x
# 4         2

# %%
(F.subs(x,2) - F.subs(x, 0)).evalf()
# Out:
# 10.0000000000000

# %%
def f(x):
    return x ** 3 - 3 * x ** 2 + x + 6

# %%
from scipy import integrate

# %%
sp.integrate.quad(f,0,2) # 정적분 수치적분
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-7a0c5ee71b08> in <module>
# ----> 1 sp.integrate.quad(f,0,2) # 정적분 수치적분
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     349
#     350     if weight is None:
# --> 351         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     352                        points)
#     353     else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     461     if points is None:
#     462         if infbounds == 0:
# --> 463             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     464         else:
#     465             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# TypeError: f() missing 1 required positional argument: 'x'

# %%
f = 3 * x ** 2 - 6 * x + 1
f
# Out:
#    2
# 3⋅x  - 6⋅x + 1

# %%
F = sympy.integrate(f)
F
# Out:
#  3      2
# x  - 3⋅x  + x

# %%
(F.subs(x,1) - F.subs(x, 0)).evalf()
# Out:
# -1.00000000000000

# %%
def f(x):
    return 3 * x ** 2 - 6 * x + 1

# %%
sp.integrate.quad(f,0,1) # 정적분 수치적분
# Out:
# (-1.0, 1.3085085171449517e-14)

# %%
f = 2 + 6 * x + 4 * sympy.exp(x) + 5 / x
f
# Out:
#          x       5
# 6⋅x + 4⋅ℯ  + 2 + ─
#                  x

# %%
F = sympy.integrate(f)
F
# Out:
#    2            x
# 3⋅x  + 2⋅x + 4⋅ℯ  + 5⋅log(x)

# %%
(F.subs(x,10) - F.subs(x, 1)).evalf()
# Out:
# 88421.5029773780

# %%
def f(x):
    return 2 + 6 * x + 4 * sympy.exp(x) + 5 / x

# %%
sp.integrate.quad(f,1,10) # 정적분 수치적분
# Out:
# (88421.50297737827, 1.5276890734473408e-06)

# %%
import numpy as np

# %%
def f(y,x):
    return np.exp(-1 * x * y) / x ** 2

sp.integrate.dblquad(f, 1, np.inf, lambda x: 0, lambda x: np.inf)
# Out:
# (0.4999999999999961, 1.0684538743333441e-08)

# %%
def f(y,x):
    return 1 + x * y

# %%
sp.integrate.dblquad(f, -1, 1, lambda x: -1, lambda x: 1)
# Out:
# (4.0, 4.440892098500626e-14)
