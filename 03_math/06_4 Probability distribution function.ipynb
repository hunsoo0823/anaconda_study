# %%
def P(a,b):
    if a < 180:
        if b <= 180:
            return (b - a) / 180 * ( 2 / 3 )
        else:
            return ( 180 - a ) / 180 * ( 2 / 3 ) + ( b - 180 ) * ( 1 / 3 )
    else:
        return (b - a) / 180  * (1 / 3)

# %%
P(0 , 180)
# Out:
# 0.6666666666666666

# %%
t = np.linspace(-100, 500, 100)
FS = np.array(list(map(P,t)))
