# %% [markdown]
# # 1주차 과제
#
# - 아래 문제의 요구사항을 먼저 확인 하시고, *#여기에 코드를 작성해주세요.* 에 요구사항에 알맞은 코드를 작성해주세요.
# - 자동 저장이 지원됩니다. 필요하시면 ctrl + s (macOS : command + s) 를 누르면 수동으로 저장이 가능합니다.
# - 도중에 인터넷 연결이 끊기는 경우에는 다시 인터넷 연결이 되면 저장 됩니다. 인터넷 연결이 끊긴 이후에는 새로고침하거나 창을 되도록 닫지 마세요.
# - 과제를 모두 완료하셨으면, Google Classroom 과제 페이지에서 우측(혹은 하단) 에 **'제출' 버튼을 눌러주세**요. '제출 취소' 로 버튼이 변경되면 정상적으로 제출된 것입니다.

# %% [markdown]
# # 멘토님 채점 및 피드백 공간 (수강생분은 수정하지 말아주세요.)
#
# ## 1번 문제
# - 1) 점
# - 2) 점
# - 3) 점
# - 4) 점
#
# ## 2번 문제
# - 1) 점
# - 2) 점

# %% [markdown]
# <hr/>
# <hr/>

# %% [markdown]
# ### 1. 아래 요구사항에 맞게 코드를 작성해주세요.
#
# - odd_even 함수를 만들어 주세요. (1점)
# - 숫자형 값을 두 개 받을 수 있게 해주세요. (1점)
# - 받은 두 숫자의 제곱을 각각 새로운 변수로 만들어 저장하세요. (1점)
# - odd_even 함수내에 조건문을 주어 새롭게 만든 변수 2개의 합이 짝수일 경우 '짝수'라는 문자열을 , 홀수일 경우 '홀수'라는 문자열을 반환하도록 해주세요.  (2점)

# %%
# 여기에 코드를 작성해주세요.
def odd_even(num1,num2):
    sqr_num1 **= num1
    sqr_num2 **= num2

# %% [markdown]
# ### 2. 아래 요구사항에 맞게 코드를 작성해주세요.
# - 아래의 예시와 같이 name, age의 변수를 포함한 Person 클래스를 만들어주세요.(2점)

# %%
 # 여기에 코드를 작성해주세요.

# %%
person = Person('Liam', '21')

# %%
person.name, person.age
# Out:
# ('Liam', '21')

# %% [markdown]
# - 위의 Person클래스를 상속받아 play의 메소드를 추가한 Child 클래스를 만들어주세요(3점)
#
#   play: print('{} is playing.'.format(name))

# %%
 # 여기에 코드를 작성해주세요.

# %%
# 아래 코드는 실행 후 결과 예 입니다.
child = Child('Olivia', '8')

# %%
child.name, child.age
# Out:
# ('Olivia', '8')

# %%
child.play()
# Out:
# Olivia is playing.
