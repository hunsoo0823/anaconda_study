# %% [markdown]
# ### 함수
# - 반복되는 코드를 묶음으로 효율적인 코드를 작성하도록 해주는 기능
# - 기본 함수
# - 파라미터와 아규먼트
# - 리턴
# - '*args','**kwargs'
# - docstring
# - scope
# - inner function
# - lambda function
# - Map, Filter, Reduce
# - Decorlator

# %% [markdown]
# ### 1. 기본함수
# - 함수의 선언과 호출

# %%
point = 88

if point >= 90:
    print("A")
elif point > 80:
    print("B")
else:
    print("C")
# Out:
# B

# %%
# 함수 선언
def grade(point):
    if point >= 90:
        print("A")
    elif point > 80:
        print("B")
    else:
        print("C")

# %%
# 함수 호출
grade(88)
# Out:
# B

# %%
# code ...

# %%
grade(78)
# Out:
# C

# %% [markdown]
# ### 2. 파라미터와 아규먼트
# - 파라미터 : 함수를 선언할때 호출하는 부분에서 보내주는 데이터를 받는 변수
# - 아규먼트 : 함수를 호출할때 함수에 보내주는 데이터

# %%
def plus(num1, num2=10,num3=20): # 파라미터 : 디폴트 파라미터
    print(num1+num2-num3)

# %%
plus(1,2) # 아규먼트
# Out:
# -17

# %%
plus(3, num3 = 100) # 아규먼트 : 키워드 아규먼트
# Out:
# -87

# %%
print(1,2, end="-")
print(3)
# Out:
# 1 2-3

# %%
def plus(num1,num2):
    print(num1+num2)
    return num1+num2

# %% [markdown]
# ### 3. 리턴
# - 함수를 실행한 결과를 저장하고 싶을때 사용한다
# - return

# %%
result = plus(1,2)
print(result)
# Out:
# 3
# 3

# %%
data1 ="python"
result = data1.upper()
print(result)
# Out:
# PYTHON

# %%
data2 = [3,1,2]
result = data2.sort()
print(result)
# Out:
# None

# %%
# 함수 선언
def grade(point):
    result = ""
    if point >= 90:
        result = "A"
    elif point > 80:
        result = "B"
    else:
        result = "C"
    return result

# %%
point = 92
result = grade(point)
print(result)
# Out:
# A

# %%
if result == "A":
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
# 함수에 return 코드가 실행되면 무조건 함수의 코드 실행이 종료
def echo(msg):
    if msg == "quit":
        return
    print(msg)

# %%
echo("python")
# Out:
# python

# %%
echo("quit")

# %% [markdown]
# ### 4. `*args`, `**kwargs`
# - 함수를 호출할때 아규먼트와 키워드 아규먼트의 갯수를 특정 지을수 없을때 사용

# %%
def plus(*args, **kwargs):
    print(type(args),args)
    print(type(kwargs),kwargs)
    return sum(args) + sum(list(kwargs.values()))

# %%
plus(1,2,3,4,5,num1=6, num2=7)
# Out:
# <class 'tuple'> (1, 2, 3, 4, 5)
# <class 'dict'> {'num1': 6, 'num2': 7}
# 28

# %%
def func(num1, num2, num3):
    return num1+num2+num3

data = [1,2,3]
func(*data) #func(1,2,3)
# Out:
# 6

# %%
data = {
    "num2" : 100,
    "num3" : 200,
}

func(1,**data) # func(1,num2=100, num3=200)
# Out:
# 301

# %% [markdown]
# ### Summary
# - 조건문
#     - if, else, elif
#     - 특정 조건에 따라서 코드를 실행하고 싶을때 사용
# - 반복문
#     - while, for
#     - 특정 코드를 반복적으로 실행 시키고 싶을때 사용
#     - continue, break

# %%
# 문장을 입력 받아서 문법에 맞도록 결과를 출력하는 코드를 작성
# 마지막 문자는 .이 있을수도 있고 없을수도 있습니다.
# python Language is the best Language
# Python language is the best language.

# 1. 문자열 입력 받기
sentence = input("input sentense :")

# 2. 모두 소문자로 변경
result = sentence.lower()

# 3. 가장 앞글자를 대문자로 변경
result = result[0].upper() + result[1:]

# 4. 마지막 문자가 . 인지 확인해서 .이 아니면 .를 추가
if result[-1] != ".":
    result += "."

result
# Out:
# input sentense :ddd
# 'Ddd.'

# %%
starks = ['john','sansa','rob','aisa','rickon','bran']
surviovor = starks[-1::-2],starks[0]
surviovor
# Out:
# (['bran', 'aisa', 'sansa'], 'john')

# %%
# 6자리의 로또번호 생성하는 코드를 작성하세요.
# 6자리의 번호는 중복이 x
import random
lotto = []

while True:
    number = str(random.randint(1,45))
    
    if number not in lotto:
        lotto.append(number)
    
    if len(lotto) >= 6:
        lotto.sort()
        break

lotto
# Out:
# ['15', '17', '19', '2', '32', '45']

# %% [markdown]
# ### 1. Docstring
#     - 함수의 설명을 작성

# %%
def echo(msg):
    "echo print msg"
    print(msg)

# %%
echo()
# Out:
# 10

# %%
def echo(msg):
    """
    
    echo func return its input argument
    The operation is:
        1. print msg parameter
        2. return msg parameter
    param : msg : str
    return : str
    """
    print(msg)
    return msg

# %%
echo?

# %%
echo??

# %%
help(echo)
# Out:
# Help on function echo in module __main__:
#
# echo(msg)
#     echo func return its input argument
#     The operation is:
#         1. print msg parameter
#         2. return msg parameter
#     param : msg : str
#     return : str

# %%
print(echo.__doc__)
# Out:
#
#     echo func return its input argument
#     The operation is:
#         1. print msg parameter
#         2. return msg parameter
#     param : msg : str
#     return : str

# %% [markdown]
# ### 2. Scope 범위
#     - 함수 안에서 선언되는 변수와 함수 밖에서 선언되는 변수의 범위가 다릅니다
#     - global(전역), local(지역)

# %%
# global

gv = 10

def echo():
    gv = 10
    print(gv)
    
echo()
# Out:
# 10

# %%
# local 
gv = 10

def echo():
    gv = 100
    print(gv)
    
echo()
# Out:
# 100

# %%
gv
# Out:
# 10

# %%
gv = 10

def echo():
    global gv
    gv = 100
    print(gv)
    
echo()
gv # 100
# Out:
# 100
# 100

# %% [markdown]
# ### 3. inner Function
#     - 함수가 지역 영역에 선언, 함수안에 함수가 선언

# %%
# 지역 함수는 전역영역에서 사용이 불가
def outer(a,b):
    
    def inner(c,d):
        return c+d
    
    return inner(a,b)

# %%
outer(1,2)
# Out:
# 3

# %%
def outer(a,b):
    
    def inner(c,d):
        print(a,b)
        return c+d
    
    return inner

# %%
outer(1,2)(3,4)
# Out:
# 1 2
# 7

# %%
# callback fuction: 함수를 아규먼트 파라미터로 설정해서 사용

# %%
def calc(func, a, b):
    # code
    a **= 2
    b **= 2
    return func(a,b)

# %%
def plus(a,b):
    return a + b

# %%
def minus(a,b):
    return a - b

# %%
calc(plus, 1, 2)
# Out:
# 5

# %%
calc(minus, 1, 2)
# Out:
# -3

# %% [markdown]
# ### 4. 람다 함수
#     - 파라미터를 간단한 계산으로 리턴되느 함수 : 삼항연산

# %%
def plsu(a,b):
    return a + b

# %%
plus(1,2)
# Out:
# 3

# %%
plus2 = lambda a, b : a + b

# %%
plus2(2,3)
# Out:
# 5

# %%
# def calc(func, a, b):
calc(lambda a, b : a * b, 3, 4)
# Out:
# 144

# %%
calc(plus, 3, 4)
# Out:
# 25

# %% [markdown]
# ### 5 . map ,filter, reduce
#         - map : 순서가 있는 데이터 집합에서 모든 값에 함수를 적용시킨 결과를 출력

# %%
ls = [1,2,3,4]
def odd_even(num):
    return "odd" if num % 2 else "even"

odd_even(3) , odd_even(4)
# Out:
# ('odd', 'even')

# %%
list(map(odd_even,ls))
# Out:
# ['odd', 'even', 'odd', 'even']

# %%
# input 함수로 구분자는 " "으로 여러개의 숫자를 입력 받습니다,.
# str.split(" ") 리스트로 만들고
# 만들어진 리스트의 값을을 int 형변환

# %%
datas = input("insert numbers :")
# Out:
# insert numbers :10 20 30 40 10 20 15

# %%
result = datas.split(" ")
result
# Out:
# ['10', '20', '30', '40', '10', '20', '15']

# %%
result = list(map(int, result))
result
# Out:
# [10, 20, 30, 40, 10, 20, 15]

# %%
# command + option 멀티라인 수정

# %% [markdown]
# #### Filter
#  - 리스트 데이터에서 특정 조건에 맞는 value만 남기는 함수

# %%
ls = range(10)

# %%
# 홀수만 출력
list(filter(lambda data: True if data % 2 else False,ls))
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# ### Reduce
#     - 리스트 데이터를 처음부터 순서대로 특정 함수를 실행하여 결과를 누적시켜 주는 함수

# %%
from functools import reduce

# %%
ls = [3,1,2,4,5]

# %%
reduce(lambda x,y : x+y, ls)
# Out:
# 15

# %% [markdown]
# ### 6. Decorlator
#     - 함수에서 코드를 바꾸지 않고 기능을 추가하거나 수정하고 싶을때 사용하는 문법
# ```
#     def a():
#         code_1
#         code_2
#         code_3
#
#     def b():
#         code_1
#         code_4
#         code_3
#
#         ... 20개
# ```

# %% [markdown]
#  - 데코레이터의 사용
# ```
#     def c(func):
#         def wrapper(*args, **kwargs):
#             code_1
#             func(*args, **kwargs)
#             code_3
#             return result
#
#         return wrapper
#
#     @c
#     def a():
#         code_2
#
#     @c
#     def b()
#         code_4
#
# ```

# %%
# a
def plus(a, b):
    print("start")
    result = a + b
    print("result : {}".format(result))
    return result

# %%
# b
def minus(a,b):
    print("start")
    result = a - b
    print("result : {}".format(result))
    return result

# %%
# c
def disp_func(func):
    def wrapper(*args, **kwargs):
        print("start")
        result = func(*args, **kwargs)
        print("result  : {}".format(result))
        return result
    return wrapper

# %%
plus(1,2)
# Out:
# start
# result : 3
# 3

# %%
minus(1,3)
# Out:
# start
# result : -2
# -2

# %%
@disp_func
def plus(a, b):
    result = a + b
    return result

# %%
plus(1,2)
# Out:
# start
# result  : 3
# 3

# %%
# 함수의 실행 시간을 출력하는 데코레이터 함수를 작성하세요.

# %%
import time

# %%
def timer(func):
    def wrapper(*args, **kwargs):
        start_time = time.time() # code 1
        result = func(*args, **kwargs)
        end_time = time.time() # code 3
        print("running time : {}".format(end_time - start_time)) # code 3
        return result
    return wrapper

# %%
@timer
def test1(num1 , num2):
    data = range(num1, num2+1)
    return sum(data)

# %%
@timer
def test2(num1, num2):
    result = 0
    for num in range(num1, num2+1):
        result += num
    return result

# %%
test1(1,100000)
# Out:
# running time : 0.003217935562133789
# 5000050000

# %%
test2(1,100000)
# Out:
# running time : 0.010841846466064453
# 5000050000

# %%
# 패스워드를 입력 받아야 함수가 실행되도록 하는 데코레이터 작성

# %%
def check_password(func):
    def wrapper(*args, **kwargs):
        pw = "dss11"
        # check password
        input_pw = input("insert pw : ")
        if input_pw == pw:
            result = func(*args, **kwargs)
        else:
            result = "not allow!"
        return result
    return wrapper

# %%
@eche
def lotto_func():
    lotto = []
    while True:
        number = str(random.randint(1,45))

        if number not in lotto:
            lotto.append(number)

        if len(lotto) >= 6:
            lotto.sort()
            break
    return lotto

# %%
def plus(a,b):
    return a + b
