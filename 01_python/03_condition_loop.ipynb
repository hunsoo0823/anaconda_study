# %% [markdown]
# ### summary
# - jupyter notebook
#     - mode : 명령모드, 편집모드
#     - style : markdown, code
#     - 단축기
#         - 실행 : shift + enter
#         - 자동완성 : tab
#         - docstring 보기 : shift + tab
#         - 주석설정 : cmd(ctrl) + /
#         - 셀 생성 : a(위에) , b(밑에)
#     - python 기본 문법
#         - 변수 선언 : RAM 저장공간에 값을 할당하는 행위
