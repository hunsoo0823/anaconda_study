# %% [markdown]
# ### summart
# - 상속 : 다른 클래스를 받아서 기능을 추가해서 새로운 클래스를 만드는 방법
# - super : 부모클래스에서 특정 함수의 코드를 가져오는 방법
# - getter, setter : 클래스로 만들어진 객체에 변수값을 수정하거나 출력할때 특정 함수를 통해서 수정하고 출력하는 방법
# - non public(private) : mangling (__), `_(클래스명)`이 붙은 변수로 객체를 생성할때 변경이 되어서 생성
# - is a / has a : 클래스를 설계하는 방법
# - magic(spacial) method
#     - 비교
#         - `__eq__`(==), `__ne__`(!=), `__lt__(<)`, `__gt__(>)`, `__le__`(<=), `__ge__(>=)`
#     - 연산
#         - `__da__`(+), `__sub__`(-), `__mul__`(`*`), `__truediv__`(/)
#         - `__floordiv__`(//), `__mod__`(%), `__pow__`(**)
#     - 그외 : `__repr__`, `__str__`

# %%
# Integer 객체
class Interger:
    def __init__(self, number):
        self.number = number
    
    def __add__(self, obj):
        return self.number + obj.number

    def __str__(self):
        return str(self.number)
    
    def __repr__(self):
        return str(self.number)

# %%
num1 = Interger(1)
num2 = Interger(2)

# %%
num1 + num2
# Out:
# 3

# %%
num1
# Out:
# 1

# %%
print(num1)
# Out:
# 1

# %%
# 클래스 계좌 클래스 만들기 
# 변수 : 자산(asset), 이자율(interest)
# 함수 : 인출(draw), 입금(insert), 이자추가(add_interst)
# 인출시 자산이상의 돈을 인출할 수 없습니다.

# %%
class account:
    def __init__(self, asset, interest):
        self.asset = asset
        self.interest = interest
    def draw(self, draw_money):
        if draw_money > self.asset:
            print("자산이상의 돈을 인출할 수 없습니다.")
            
        else:
            self.asset -= draw_money
            print("{}원의 자산을 인출하셨습니다.".format(draw_money))
            print("{}원의 잔액이 남았습니다.".format(self.asset))
            
    def insert(self, insert):
        self.asset += insert
        print("{}원의 자산을 입금하셨습니다.".format(insert))
        print("{}원의 잔액이 남았습니다.".format(self.asset))
        
    def add_interest(self, interest):
        self.interest += interest
        print("현재 이자율은 {}% 입니다.".format(self.interest))

# %%
acc1 = account(5000, 20)

# %%
acc1.draw(100)
# Out:
# 100원의 자산을 인출하셨습니다.
# 4900원의 잔액이 남았습니다.

# %%
acc1.insert(200)
# Out:
# 200원의 자산을 입금하셨습니다.
# 5100원의 잔액이 남았습니다.

# %%
acc1.add_interest(2)
# Out:
# 현재 이자율은 22% 입니다.

# %% [markdown]
# ### Module Package
# - 모듈 : 변수, 함수, 클래스를 모아 놓은 (.py) 확장자를 가진 파일
# - 패키지 : 모듈의 기능을 디렉토리별로 정리해 놓은 개념

# %% [markdown]
# ### 1. 모듈
# - 모듈 생성
# - 모듈 호출

# %%
# !ls
# Out:
# 01_juptyer_notebook.ipynb 04_function.ipynb         08_module_package.ipynb
# 02_basic_syntax.ipynb     05_class_1.ipynb          dss.py
# 03_condition_loop.ipynb   06_class_2.ipynb

# %%
# %%writefile dss.py

num = 1234

def disp1(msg):
    print("disp1", msg)

def disp2(msg):
    print("disp2", msg)
    
class Calc:
    def plus(self, *args):
        return sum(args)
# Out:
# Writing dss.py

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %whos
# Out:
# Interactive namespace is empty.

# %%
# 모듈 호출 : import
import dss

# %%
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# dss        module    <module 'dss' from '/User<...>s/dss0/01_python/dss.py'>

# %%
dss.num
# Out:
# 1234

# %%
dss.disp1("python")
# Out:
# disp1 python

# %%
calc = dss.Calc()

# %%
calc.plus(1,2,3,4)
# Out:
# 10

# %%
import random

# %%
random.randint(1,5)
# Out:
# 4

# %%
# 모듈 안에 특정 함수, 변수, 클래스 호출

# %%
from dss import num, disp2

# %%
# %whos
# Out:
# Variable   Type        Data/Info
# --------------------------------
# calc       Calc        <dss.Calc object at 0x7fe6cb7c4640>
# disp2      function    <function disp2 at 0x7fe6c9d3a4c0>
# dss        module      <module 'dss' from '/User<...>s/dss0/01_python/dss.py'>
# num        int         1234
# random     module      <module 'random' from '/U<...>lib/python3.8/random.py'>

# %%
dss.num
# Out:
# 1234

# %%
num
# Out:
# 1234

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# 모듈의 모든 변ㅅ수를 가져옴
from dss import *

# %%
# %whos
# Out:
# Variable   Type        Data/Info
# --------------------------------
# Calc       type        <class 'dss.Calc'>
# disp1      function    <function disp1 at 0x7fe6c9d3adc0>
# disp2      function    <function disp2 at 0x7fe6c9d3a4c0>
# num        int         1234

# %% [markdown]
# ### 2. Package
# - 패키지 생성
# - 패키지 호출
# - setup.py 패키지 설치 파일 만들기

# %%
# 디렉토리 생성

# %%
# !mkdir -p school/dss

# %%
# !mkdir -p school/web
