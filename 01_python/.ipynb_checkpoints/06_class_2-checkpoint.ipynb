# %% [markdown]
# ### Summary
# - function
#     - docstring
#     - scope : 전역, 지역 : global
#     - inner function : 함수안에 함수를 선언
#     - lambda function : 간략한 함수를 한줄의 코드로 작성
#     - decorator : 특정 기능을 데코레이터 함수로 만들어 함수에 특정 기능을 적용하는 방법
# - class
#     - 변수와 함수들이 모여있는 집합
#     - 기본 클래스 사용법
#         - 클래스 선언 -> 객체로 만듦 -> 객체에 함수를 호출
#     - 생성자 함수
#         - 클래스가 객체로 만들어 질때, 객체에 선언되는 변수를 설정하는 방법

# %%
user_datas = [
    {"id":"test","pw":"1234","count":0},
    {"id":"python","pw":"5678","count":0},
]

# %%
# user_data 를 입력받아서 아이디와 패스워드를 체크하는 데코레이터 함수를 코드를 작성하세요.
# 로그인 될때마다 count를 1씩 증가
def need_login(func):
    def wrapper(*args, **kwargs):
        # 아이디 패스워드 입력
        user,pw = tuple(input("insert user pw : ").split(" "))
        
        for user_data in user_datas:
            if user_data["id"] == user: # 존재하는 아이디인지 확인
                if user_data["pw"] == pw: # 존재하면 패스워드 확인
                    user_data["count"] += 1
                    result = func(*args, **kwargs)
        # 카운트 증가 및 함수 실행
        return result
    return wrapper

# %%
@need_login
def plus(num1, num2):
    return num1 + num2

# %%
user,pw = tuple(input("insert user pw : ").split(" "))
user,pw

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-14d0c77ccf90> in <module>
# ----> 1 user_datas["id"]
#
# TypeError: list indices must be integers or slices, not str
