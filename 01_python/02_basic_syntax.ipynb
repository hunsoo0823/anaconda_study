# %% [markdown]
# ### 파이썬의 기본 문법
#  - 변수 선언, 식별자, 자료형, 형변환, 연산자 학습

# %% [markdown]
# 1. 주석(comment)과 출력(print)

# %%
# 주석 : 앞에 #을 붙이면 코드로 실행이 안됩니다.
# 코두에 대한 설명이나 중간에 코드를 실행시키고 싶지 않을떄 사용

print(1)
# print(2)
print(3)
# Out:
# 1
# 3

# %%
# 출력 : print 함수
# 코드 중간에 변수에 들어있는값을 확인하고 싶을때 사용

# %%
a = 1
b = 2
print(b)
c= 3
b = 4
print(b)
# Out:
# 2
# 4

# %%
# print 함수의 옵션
# docstring : 함수에 대한 설명 : 단축기(shift + tab)
# 자동완성 : tab
print(1, 2, sep="-", end="\t")
print(3)
print
# Out:
# 1-2	3

# %%
print_data_science = 1

# %% [markdown]
# 2. 변수 선언
#     - RAM 저장공간에 값을 할당하는 행위

# %%
a = 1
b = 2
c = a+b
c
# Out:
# 3

# %%
d, e = 3, 4
f = g = 5

# %% [markdown]
# 3. 식별자
#     - 변수, 함수, 클래스, 모듈등의 이름을 식별자 라고 합니다.
#     - 식별자 규칙
#         - 소문자, 대문자, 숫자, 언더 스코어(_)를 사용합니다,
#         - 가장 앞에 숫자 사용 불가
#         - 예약어의 사용 불가 : def, class, try, except
#         - 컨벤션
#             - snake case : fast_campus : 변수, 함수
#             - camel case : FaseCampus, fastCampus : 클래스

# %%
# 10a = 5

# %%
# def = 1
