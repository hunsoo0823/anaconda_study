# %%
xx = np.linspace(-5,5,100)
plt.plot(xx, 1/(1+np.exp(-xx)), 'r-', label="로지스틱 함수")
plt.plot(xx, sp.special.erf(0.5*np.sqrt(np.pi)*xx), 'g:', label="오차함수")
plt.plot(xx, np.tanh(xx), 'b--', label="하이퍼볼릭탄젠트함수")
plt.ylim([-1.1,1.1])
plt.legend(loc=2)
plt.xlabel("x")
plt.show()

# %%
from sklearn.datasets import make_classificationl

# X0, y = make_classification(n_features=1, n_redundatnt=0, n_informative=1, n_clusters_per_class=1, random_state=4)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-08b17aa7703e> in <module>
# ----> 1 from sklearn.datasets import make_classificationl
#       2
#       3 # X0, y = make_classification(n_features=1, n_redundatnt=0, n_informative=1, n_clusters_per_class=1, random_state=4)
#
# ImportError: cannot import name 'make_classificationl' from 'sklearn.datasets' (/Users/songhyeonsu/opt/anaconda3/lib/python3.8/site-packages/sklearn/datasets/__init__.py)
