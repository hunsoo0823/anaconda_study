# %%
import scipy as sp

img_gray = sp.misc.face(gray=True)
img_gray.shape
# Out:
# (768, 1024)

# %%
import PIL
PIL.__version__
# Out:
# '8.0.1'

# %%
# !wget -O logo.png https://c.files.bbci.co.uk/12A9B/production/_111434467_gettyimages-1143489763.jpg
# Out:
# --2021-04-24 18:54:56--  https://c.files.bbci.co.uk/12A9B/production/_111434467_gettyimages-1143489763.jpg
# Resolving c.files.bbci.co.uk (c.files.bbci.co.uk)... 2600:1410:4000:195::f33, 2600:1410:4000:182::f33, 2600:1410:4000:189::f33, ...
# Connecting to c.files.bbci.co.uk (c.files.bbci.co.uk)|2600:1410:4000:195::f33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56803 (55K) [image/jpeg]
# Saving to: `logo.png'
#
# logo.png            100%[===================>]  55.47K  --.-KB/s    in 0.03s
#
# 2021-04-24 18:54:56 (1.63 MB/s) - `logo.png' saved [56803/56803]

# %%
from PIL import Image

img_logo_png = Image.open("./logo.png")
img_logo_png.size
# Out:
# (976, 549)

# %%
img_logo_png
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=976x549 at 0x7FF60CABC7C0>

# %%
img_logo_png.save("./logo.bmp")
img_logo_bmp = Image.open("./logo.bmp")

# %%
img_logo_array = np.array(img_logo_bmp)

plt.imshow(img_logo_array)
plt.axis("off")
plt.show()

# %%
Image.fromarray(img_logo_array)
# Out:
# <PIL.Image.Image image mode=RGB size=976x549 at 0x7FF60DFC2910>

# %%
img_logo_png2 = img_logo_png.resize((300,100))
img_logo_png2
# Out:
# <PIL.Image.Image image mode=RGB size=300x100 at 0x7FF60CB641F0>

# %%
img_logo_thumbnail = img_logo_png.copy()
img_logo_thumbnail.thumbnail((150, 50))
img_logo_thumbnail
# Out:
# <PIL.Image.Image image mode=RGB size=89x50 at 0x7FF60DFB6790>

# %%
img_logo_rotated = img_logo_png.rotate(45)
img_logo_rotated
# Out:
# <PIL.Image.Image image mode=RGB size=976x549 at 0x7FF60CB641C0>

# %%
img_logo_cropped = img_logo_png.crop((10,10,200,200))
img_logo_cropped
# Out:
# <PIL.Image.Image image mode=RGB size=190x190 at 0x7FF60CB642B0>

# %%
import skimage
skimage.__version__
# Out:
# '0.17.2'

# %%
import skimage.data

img_astro = skimage.data.astronaut()
img_astro.shape
# Out:
# (512, 512, 3)

# %%
skimage.io.imsave("astronaut.png", img_astro)
img_astro2 = skimage.io.imread("astronaut.png")

# %%
from skimage import color

plt.subplot(131)
plt.imshow(img_astro)
plt.axis("off")
plt.title("RGB")
# Out:
# Text(0.5, 1.0, 'RGB')

# %%
import cv2
cv2.__version__
# Out:
# '4.5.1'

# %%
img_astro3 = cv2.imread("./astronaut.png")
img_astro3.shape
# Out:
# (512, 512, 3)

# %%
b, g, r  = cv2.split(img_astro3)
img_astro3_rgb = cv2.merge([r,g,b])
